# %% [markdown]
# <a href="https://colab.research.google.com/github/therealcaesar-si/EMSC2010-W9-L1-u7567593/blob/main/EMSC2010_W9_L1_NB2_u7567593.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W9-L1-NB2
#
# #### The logistic population model:
#
# $x_{\mathrm{next}} = a x_{\mathrm{initial}}(1-x_{\mathrm{initial}})$
#
# where:
# * $x$ is the population size between 0 and 1.
# * $x_{\mathrm{initial}}$ is the current population size
# * $x_{\mathrm{next}}$ is next year's population size
# * $a$ is the ability to reproduce.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
### Code the logistic population model
a = 3.6 # a equals fuckability
h = 0.22 # h equals harvesting of a population
x = np.zeros(50)
x[0] = 0.5

for i in range(1,50):
  x[i] = a * x[i-1] * (1 - x[i-1]) - h # The magical calculation
  x[i] = np.maximum(x[i],0)
  #x[i] = np.minimum(x[i],1)

plt.plot(x)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Logistic Population Model')
plt.ylim(0,1)
plt.xlim(0,50)
plt.show()
#x_initial = 0.576
#x_next = a * x_initial * (1 - x_initial)
#print(x_next)

# %% [markdown]
# #### The logistic population model with harvesting:
#
# $x_{\mathrm{next}} = a x_{\mathrm{initial}}(1-x_{\mathrm{initial}}) - h$
#
# where:
# * $x$ is the population size between 0 and 1.
# * $x_{\mathrm{initial}}$ is the current population size.
# * $x_{\mathrm{next}}$ is next year's population size.
# * $a$ is the ability to reproduce.
# * $h$ is the size of the harvest between 0 and 1.

# %%
### Code the logistic population model with harvesting

#See above lol

# %% [markdown]
# #### The logistic population model with randomness:
#
# $x_{\mathrm{next}} = (a+r) x_{\mathrm{initial}}(1-x_{\mathrm{initial}})$
#
# where:
# * $x$ is the population size between 0 and 1.
# * $x_{\mathrm{initial}}$ is the current population size.
# * $x_{\mathrm{next}}$ is next year's population size.
# * $a$ is the ability to reproduce.
# * $r$ is a normally distributed random number that changes each year.

# %%
### Code the logistic population model with randomness

a = 3.2 # a equals fuckability
h = 0.1 # h equals harvesting of a population
x = np.zeros(100)
x[0] = 0.9

for i in range(1,100):
  r = np.random.randn() * 0.1 # Random environmental variability
  x[i] = (a + r) * x[i-1] * (1 - x[i-1]) - h # The magical calculation
  x[i] = np.maximum(x[i],0)
  #x[i] = np.minimum(x[i],1)

plt.plot(x)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Logistic Population Model')
plt.ylim(0,1)
plt.xlim(0,100)
plt.show()

# %% [markdown]
# #### The logistic map:
#
# $x_{\mathrm{next}} = a x_{\mathrm{initial}}(1-x_{\mathrm{initial}})$
#
# where:
# * $x$ is the population size between 0 and 1.
# * $x_{\mathrm{initial}}$ is the current population size
# * $x_{\mathrm{next}}$ is next year's population size
# * $a$ is the ability to reproduce.
#
# Follow these steps:
#
# 1. Choose a random value of $a$ from 0 to 4.
#
# 2. Choose a random starting population x_{\mathrm{initial}} from 0 to 1
#
# 3. Run the model for 2,000 generations and record the $x$ value of the last generation.
#
# 4. Repeat steps 1-3 a large number of times (thousands)
#
# 5. Make a scatter plot of $a$ (x-axis) versus final $x$ (y-axis).

# %%
### Code the logistic map

a = np.random.rand()*4
x = np.random.rand()
x = a*x*(1-x)
#x[0] = np.random.rand()

for i in range(2000):
#  x[i] = a * x[i-1] * (1 - x[i-1])
  x = a*x*(1-x)

print(x)
#print(a)
# Out:
# 0.8200352010602908

# %%
# Loopception!

for j in range(10):
  a = np.random.rand()
  x = np.random.rand()
  for i in range(2000):
    x = a * x * (1-x)
print(x)
# Out:
# 1.1456492819699146e-153

# %%
# Loopception 2!!!
# store the a and x
a_out = []
x_out = []
for j in range(100000):
  a = np.random.rand()*0.3+3.8
  a_out.append(a)
  x = np.random.rand()
  for i in range(2000):
    x = a * x * (1-x)
  x_out.append(x)
print(x_out)
# Out:
# [-inf, 0.9579679295835228, -inf, 0.8639536937656483, 0.3373354137522586, -inf, -inf, 0.6101149349742834, -inf, 0.9938639171650823, 0.42745099568000594, 0.16601755920189978, -inf, -inf, -inf, 0.1546219252735993, 0.7722251418117414, -inf, -inf, 0.14067651745391763, 0.2297588493774068, 0.849168968262348, 0.643711210186342, -inf, 0.7566431804088628, -inf, 0.1598581725056203, 0.9858008960058868, -inf, -inf, 0.024855680045260994, -inf, -inf, 0.9580172831117757, -inf, -inf, 0.9578958834106235, 0.9240693408982662, 0.08809845483598686, 0.489302646644808, 0.4948820914646412, 0.179927107498829, -inf, 0.15805379390566748, -inf, 0.1626774218929939, 0.4967970060359179, -inf, 0.9945562400734154, 0.6915774517392563, 0.4993381705442337, 0.4637339901212619, 0.6762767008104249, -inf, 0.9901334154803674, 0.2779957443970976, -inf, 0.8266593066656526, -inf, 0.9150275561716724, 0.9592372959873873, 0.32892844538186555, 0.7570009509569497, -inf, -inf, -inf, -inf, -inf, 0.9372214796464315, 0.1789344898375347,
# ...

# %%
plt.plot(a_out,x_out,'.', markersize=0.2)
plt.xlabel('a')
plt.ylabel('x')
#plt.xlim(0,4)
plt.ylim(0,1)
plt.title('Logistic Map')
plt.show()
