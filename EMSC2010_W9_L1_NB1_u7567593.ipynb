# %% [markdown]
# <a href="https://colab.research.google.com/github/therealcaesar-si/EMSC2010-W9-L1-u7567593/blob/main/EMSC2010_W9_L1_NB1_u7567593.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W9-L1-NB1
# Model Earth's surface temperature (in Kelvin) using a zero-dimensional energy balance model without an atmosphere.
#
# $T_e = \left[ \frac{S}{4 \alpha} (1-A)\right]^{1/4}$
#
# where:
# * $T_e$ is Earth's surface temperature in Kelvin
# * $S$ is the solar flux (1366 W/m$^2$)
# * $A$ is albedo (currently around 0.3)
# * $\alpha$ is the Stefan-Boltmann constant (5.67E-8 W/m$^2$/K$^4$)

# %%
S = 1366
A = 0.3
Sigma = 5.67e-8
print(S, A, Sigma)
# Out:
# 1366 0.3 5.67e-08

# %%
#Normal parameters
Te = pow(((S/(4*Sigma))*(1-A)), (1/4))
print(Te, "Kelvin, ", Te-273.15, "Celsius")
# Out:
# 254.81584054796193 Kelvin,  -18.33415945203805 Celsius

# %%
A = 0.0 # Albedo = nothin!
Te = pow(((S/(4*Sigma))*(1-A)), (1/4))
print(Te, "Kelvin, ", Te-273.15, "Celsius")
# Out:
# 278.5812689476053 Kelvin,  5.431268947605304 Celsius

# %%
A = 0.3 # albedo is normal but...
Sn = S*0.9 # the Sun is being eaten by astrophages!
Te = pow(((Sn/(4*Sigma))*(1-A)), (1/4))
print(Te, "Kelvin, ", Te-273.15, "Celsius")
# Out:
# 248.19158334222595 Kelvin,  -24.958416657774023 Celsius

# %%
import numpy as np
import matplotlib.pyplot as plt
